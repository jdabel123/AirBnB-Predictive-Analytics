# %% [markdown]
# ##  Sleeping Sound in Seattle: Descriptive and Predictive Analytics

# %%
#Import revelevant libraries.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Business Understanding
#
#
# I want to find out what Airbnb guests value most when evaluating listings. Using this information it could help hosts make their listings more attractive to potential guests, whilst also improving the experience for guests in turn. I will try and answer questions like:
#
# - Is it important to achieve Superhost status?
# - How do guests percieve the cleaning fee?
# - Is their a relationship between property type and price?

# %%
#Import listings and reviews data

listings = pd.read_csv(r'C:\Users\johna\OneDrive\Desktop\udacity\listings.csv')

# %%
listings.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
listings.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.818000e+03  3.818000e+03  3.818000e+03          3816.000000
# mean   5.550111e+06  2.016010e+13  1.578556e+07             7.157757
# std    2.962660e+06  0.000000e+00  1.458382e+07            28.628149
# min    3.335000e+03  2.016010e+13  4.193000e+03             1.000000
# 25%    3.258256e+06  2.016010e+13  3.275204e+06             1.000000
# 50%    6.118244e+06  2.016010e+13  1.055814e+07             1.000000
# 75%    8.035127e+06  2.016010e+13  2.590309e+07             3.000000
# max    1.034016e+07  2.016010e+13  5.320861e+07           502.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                3816.000000  3818.000000  3818.000000   3818.000000
# mean                    7.157757    47.628961  -122.333103      3.349398
# std                    28.628149     0.043052     0.031745      1.977599
# ...

# %%
listings.columns.values
# Out:
# array(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name',
#        'summary', 'space', 'description', 'experiences_offered',
#        'neighborhood_overview', 'notes', 'transit', 'thumbnail_url',
#        'medium_url', 'picture_url', 'xl_picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode',
#        'market', 'smart_location', 'country_code', 'country', 'latitude',
#        'longitude', 'is_location_exact', 'property_type', 'room_type',
# ...

# %%
#Secelecting the revelevant columns

df = listings[["host_response_rate","host_response_time", "host_acceptance_rate", "host_is_superhost",
               "host_listings_count", "zipcode", "property_type","room_type", "accommodates", "bathrooms", "bedrooms", 
               "beds", "price", "number_of_reviews","cleaning_fee","review_scores_cleanliness", "review_scores_rating", "cancellation_policy", 
               "reviews_per_month",'availability_365']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c8522001b61e> in <module>
#       1 #Secelecting the revelevant columns
#       2
# ----> 3 df = listings[["host_response_rate","host_response_time", "host_acceptance_rate", "host_is_superhost",
#       4                "host_listings_count", "zipcode", "property_type","room_type", "accommodates", "bathrooms", "bedrooms",
#       5                "beds", "price", "number_of_reviews","cleaning_fee","review_scores_cleanliness", "review_scores_rating", "cancellation_policy",
#
# NameError: name 'listings' is not defined

# %% [markdown]
# ## 2. Data Understanding

# %%
#% of NaN values

(len(df) - df.count()) / len(df) * 100
# Out:
# host_response_rate           13.698271
# host_response_time           13.698271
# host_acceptance_rate         20.246202
# host_is_superhost             0.052383
# host_listings_count           0.052383
# zipcode                       0.183342
# property_type                 0.026192
# room_type                     0.000000
# accommodates                  0.000000
# bathrooms                     0.419068
# bedrooms                      0.157150
# beds                          0.026192
# price                         0.000000
# number_of_reviews             0.000000
# cleaning_fee                 26.977475
# review_scores_cleanliness    17.103195
# review_scores_rating         16.946045
# cancellation_policy           0.000000
# reviews_per_month            16.422211
# availability_365              0.000000
# dtype: float64

# %%
df.dtypes
# Out:
# host_response_rate            object
# host_response_time            object
# host_acceptance_rate          object
# host_is_superhost             object
# host_listings_count          float64
# zipcode                       object
# property_type                 object
# room_type                     object
# accommodates                   int64
# bathrooms                    float64
# bedrooms                     float64
# beds                         float64
# price                         object
# number_of_reviews              int64
# cleaning_fee                  object
# review_scores_cleanliness    float64
# review_scores_rating         float64
# cancellation_policy           object
# reviews_per_month            float64
# availability_365               int64
# dtype: object

# %% [markdown]
# ## 3. Data Preparation
#
# - Filling missing values with the mean value for the respective column.
# - Handling categorical data by creating dummy variables.

# %%
#Cleaning data

"""
I chose to impute the missing with the mean for the respective columns. I chose this method instead of dropping
the rows with missing values because the largest percentage of missing values was 29% for cleaning_fee.

"""

df['host_response_rate'] = df['host_response_rate'].str.replace('%','').astype('float64')
df['host_acceptance_rate'] = df['host_acceptance_rate'].str.replace('%','').astype('float64')

df['host_is_superhost'] = np.where(df['host_is_superhost'] == 't',1,0)

df['price'] = df['price'].str.replace('[$, ]','').astype('float64')

df['cleaning_fee'] = df['cleaning_fee'].str.replace('[$, ]','').astype('float64')

# %%
#Filling in missing values
fill_missing = lambda col:col.fillna(col.mean())    
    
def filling_numerical_missing_values(df,function):
    """
    Function to fill in the missing values in the dataframe that are numerical data types with the desired value
    
    INPUT:
    
    df - The dateframe that you want to impute missing values
    
    function - The desired function to impute missing values
    
    OUTPUT:
    
    The function will return the data frame with imputed missing values for numerical data types.
    """
    
    
    num_vars = df.select_dtypes(include=['float64','int64']).copy()
    
    filled_num_vars = num_vars.apply(function,axis=1)
    
    # Reassigning columns in original data frame with the columns in filled_num_vars
    
    for col in filled_num_vars:
        df[col] = filled_num_vars[col]
        
    return df

df = filling_numerical_missing_values(df,fill_missing)

# %%
#Plot to show distribution of listing price

average = np.average(df['price'])

sns.distplot(df['price']);

plt.title("Distribution of Prices in Seattle")

plt.axvline(x=average,color ='red')

plt.text(x=average + 10, y=0.007,s="Average Listing Price: ${}".format(int(round(average,1))),label="Average")

plt.ylabel("Probability")


plt.xlabel("Price");

# %%
#Scatter plot to show relationship between price and bedrooms

plt.scatter(df['price'],df['bedrooms'])
plt.ylabel('bedrooms')
plt.xlabel('Listing price in $')
plt.title('No. of bedrooms vs price')
plt.ylim(0,20);

# %%
#Plot to show relationship between price and review rating
sns.jointplot(x='review_scores_rating',y='price',data=df)
plt.xlabel('Review Ratings');

# %%
# plot to show relatonship between availability and price

sns.jointplot(x='availability_365',y = 'price',data=df);

# %%
#Will being a superuser effect the demand?

super_df = df[df['host_is_superhost'] == 1]
non_super_df = df[df['host_is_superhost']==0]

fig = plt.figure(figsize=(15,5))



ax1 = fig.add_subplot(1,2,1)
ax1 = sns.distplot(super_df['availability_365'], hist=False,color='cornflowerblue',kde_kws={'shade':True})
ax1 = sns.distplot(non_super_df['availability_365'],hist=False,color='peru',kde_kws={'shade':True})
ax1 = plt.legend(['Superhost','Not Superhost'],loc=2,frameon=False)
ax1 = plt.xlim(0,365)
ax1 = plt.xlabel("Availability Remaining in Days")
ax1 = plt.title("Superhost status affect on demand")

ax2 = fig.add_subplot(1,2,2)
ax2 = sns.distplot(super_df['price'], hist=False,color='cornflowerblue',kde_kws={'shade':True})
ax2 = sns.distplot(non_super_df['price'],hist=False,color='peru',kde_kws={'shade':True})
ax2 = plt.legend(['Superhost','Not Superhost'],loc=9,frameon=False)
ax2 = plt.xlabel("Listing Price $")
ax2 = plt.title("Superhost status affect on price")

# %%
#relationship between property type and price


sns.factorplot(x='property_type',y='price',data=df,kind='box',size=7)

plt.ylabel('Lising price $')
plt.xlabel('Property Type')
plt.title('Property type vs Price')
plt.xticks(rotation = 90);

# %%
#Host reponse time effect on availability?

temp_df = df[['availability_365','host_response_time']]

tdf_1 = temp_df[(temp_df['host_response_time'] == 'within a few hours')]

tdf_2 = temp_df[(temp_df['host_response_time'] == 'within an hour')]

tdf_3 = temp_df[(temp_df['host_response_time'] == 'within a day')]

tdf_4 = temp_df[(temp_df['host_response_time'] == 'a few days or more')]


sns.distplot(tdf_1['availability_365'],hist=False,label = 'within a few hours')
sns.distplot(tdf_2['availability_365'],hist=False,label ='within an hour' )
sns.distplot(tdf_3['availability_365'],hist=False,label = 'within a day')
sns.distplot(tdf_4['availability_365'],hist=False,label = 'a few days or more')


plt.title('Effect of Response Time on Demand')
plt.xlabel('Availability')

plt.ylabel('Probability Density')

plt.legend(frameon = False)

plt.xlim(0,450);

# %%
# How does the cleaning fee affect the price?
fig = plt.figure()

fig.set_figwidth(15)

ax1 = fig.add_subplot(121)


clean = listings[['price','cleaning_fee','availability_365']]

clean['price'] = clean['price'].str.replace('[$, ]','').astype('float64')

df_clean_fee = clean[clean['cleaning_fee'].isnull() == False]
df_no_fee = clean[clean['cleaning_fee'].isnull() == True]

df_clean_fee
ax1 = sns.distplot(df_clean_fee['price'],hist=False,color ='blue',kde_kws={'shade':True})
ax1 = sns.distplot(df_no_fee['price'],hist=False,color='green',kde_kws={'shade':True})


ax1 = plt.title("Effect of cleaning fee on price?")
ax1 = plt.ylabel("Probability")
ax1 = plt.xlabel("Listing Price $")
plt.legend(['Cleaning Fee','No Cleaning Fee'],frameon=False)

ax2 = fig.add_subplot(122)

ax2 = sns.distplot(df_clean_fee['availability_365'],hist=False,color ='blue',kde_kws={'shade':True})
ax2 = sns.distplot(df_no_fee['availability_365'],hist=False,color='green',kde_kws={'shade':True})
ax2 = plt.legend(['Cleaning Fee','No Cleaning Fee'],loc=2,frameon=False)
ax2 = plt.xlim(0,365)
ax2 = plt.xlabel("Availability of Listing in Days")
ax2 = plt.ylabel("Probability")
ax2 = plt.title("Effect of cleaning fee on availability?")




#What about availability

# %% [markdown]
# ## Creating a Linear Regression model to try and predict price.

# %% [markdown]
# Creating dummy variables for categorical data

# %%
sns.heatmap(df.corr(),cbar=True);

# %%
#Getting categorical data

cat_var = df.select_dtypes(include='object')

cat_var
# Out:
#       host_response_time zipcode property_type        room_type  \
# 0     within a few hours   98119     Apartment  Entire home/apt
# 1         within an hour   98119     Apartment  Entire home/apt
# 2     within a few hours   98119         House  Entire home/apt
# 3                    NaN   98119     Apartment  Entire home/apt
# 4         within an hour   98119         House  Entire home/apt
# ...                  ...     ...           ...              ...
# 3813  within a few hours   98107         House  Entire home/apt
# 3814      within an hour   98102     Apartment  Entire home/apt
# 3815                 NaN   98178         House  Entire home/apt
# 3816      within an hour   98112   Condominium  Entire home/apt
# 3817        within a day   98109     Apartment  Entire home/apt
#
#      cancellation_policy
# 0               moderate
# 1                 strict
# 2                 strict
# 3               flexible
# 4                 strict
# ...                  ...
# ...

# %%
for col in cat_var.columns:
    df = pd.concat([df.drop(col,axis=1), pd.get_dummies(df[col], prefix=col, prefix_sep='-', drop_first=True)],axis=1)

# %%
df
# Out:
#       host_response_rate  host_acceptance_rate  host_is_superhost  \
# 0              96.000000            100.000000                  0
# 1              98.000000            100.000000                  1
# 2              67.000000            100.000000                  0
# 3              31.250000             31.250000                  0
# 4             100.000000             91.991538                  0
# ...                  ...                   ...                ...
# 3813           99.000000            100.000000                  0
# 3814          100.000000            100.000000                  0
# 3815           24.666667             24.666667                  0
# 3816          100.000000             42.800000                  0
# 3817          100.000000             22.500000                  0
#
#       host_listings_count  accommodates  bathrooms  bedrooms  beds  price  \
# 0                     3.0           4.0        1.0       1.0   1.0   85.0
# ...

# %% [markdown]
# ## 4. Modelling
#
# - Using a linear regression model to try and predict the listing price based on a variety of variables.

# %%
#Split the data into test and train set 

X = df.drop('price',axis=1)

y = df['price']


X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.3, random_state = 42)

#Instantiate model: I have chosen fit_intercept = False because when fit_intercept = False the model predicts very high values
#for the test data.

lm_model = LinearRegression(normalize=True,fit_intercept=False)


#Train the model

lm_model.fit(X_train,y_train)

#Predict using x test values

y_test_pred = lm_model.predict(X_test)

y_train_pred = lm_model.predict(X_train)


#Measure r2 score

test_r2_score = r2_score(y_test,y_test_pred)
train_r2_score = r2_score(y_train,y_train_pred)

print("Test R2 score: {}".format(test_r2_score))
print("Train R2 score: {}".format(train_r2_score))
# Out:
# Test R2 score: 0.576406389334699
# Train R2 score: 0.601266670689475

# %% [markdown]
# ## 5. Evaluation

# %%
plt.scatter(y_train_pred,y_train_pred - y_train,color = 'dodgerblue')
plt.scatter(y_test_pred,y_test_pred - y_test, color='crimson',alpha=.6)

plt.ylabel('Residuals')
plt.xlabel('Price')

plt.title("The residuals from Train and Test values")

plt.legend(['Training data','Test data'],frameon=False);

# %%
coefficients = pd.concat([pd.DataFrame(X.columns),pd.DataFrame(np.transpose(lm_model.coef_))], axis = 1)

column_names = ['Features','coef_']

coefficients.columns = column_names

coefficients = coefficients.sort_values(by='coef_',ascending=False).reset_index()

coefficients.head()
# Out:
#    index                       Features       coef_
# 0     45             property_type-Boat  120.542660
# 1     49           property_type-Chalet   50.314676
# 2     36                  zipcode-98134   40.196654
# 3     44  property_type-Bed & Breakfast   31.212546
# 4     48        property_type-Camper/RV   25.778267

# %%
coefficients.tail()
# Out:
#     index                               Features       coef_
# 58     15  host_response_time-within a few hours  -60.753863
# 59     14        host_response_time-within a day  -61.684341
# 60     40                          zipcode-98177  -71.402913
# 61     16      host_response_time-within an hour  -74.743262
# 62     51                     property_type-Dorm -111.306642
